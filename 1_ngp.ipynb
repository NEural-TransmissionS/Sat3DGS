# %% [markdown]
# # Train

# %%
# screen -dmS ngp_Case_I -L -Logfile ngp_Case_I.log sh -c 'CUDA_VISIBLE_DEVICES=0 python instant-NeRF/scripts/run.py --mode nerf --scene data_ns/Case_I/transforms_train.json --save_snapshot models/ngp/Case_I/base.msgpack --n_steps 50000'
# screen -dmS ngp_Case_II -L -Logfile ngp_Case_II.log sh -c 'CUDA_VISIBLE_DEVICES=1 python instant-NeRF/scripts/run.py --mode nerf --scene data_ns/Case_II/transforms_train.json --save_snapshot models/ngp/Case_II/base.msgpack --n_steps 50000'
# screen -dmS ngp_Case_III -L -Logfile ngp_Case_III.log sh -c 'CUDA_VISIBLE_DEVICES=0 python instant-NeRF/scripts/run.py --mode nerf --scene data_ns/Case_III/transforms_train.json --save_snapshot models/ngp/Case_III/base.msgpack --n_steps 50000'
# screen -dmS ngp_Case_IV -L -Logfile ngp_Case_IV.log sh -c 'CUDA_VISIBLE_DEVICES=1 python instant-NeRF/scripts/run.py --mode nerf --scene data_ns/Case_IV/transforms_train.json --save_snapshot models/ngp/Case_IV/base.msgpack --n_steps 50000'

# %% [markdown]
# # Render

# %%
# !python instant-NeRF/scripts/run.py --mode nerf --load_snapshot models/ngp/Case_I/base.msgpack --screenshot_transforms data_ns/Case_I/transforms_test.json --screenshot_dir models/ngp/Case_I/
# !python instant-NeRF/scripts/run.py --mode nerf --load_snapshot models/ngp/Case_II/base.msgpack --screenshot_transforms data_ns/Case_II/transforms_test.json --screenshot_dir models/ngp/Case_II/
# !python instant-NeRF/scripts/run.py --mode nerf --load_snapshot models/ngp/Case_III/base.msgpack --screenshot_transforms data_ns/Case_III/transforms_test.json --screenshot_dir models/ngp/Case_III/
# !python instant-NeRF/scripts/run.py --mode nerf --load_snapshot models/ngp/Case_IV/base.msgpack --screenshot_transforms data_ns/Case_IV/transforms_test.json --screenshot_dir models/ngp/Case_IV/
# Out:
# ...
# 18:19:12 SUCCESS  Initialized CUDA 11.8. Active GPU is #0: NVIDIA GeForce RTX 3080 Ti [86]
# 18:19:12 SUCCESS  Detected auxiliary GPUs:
# 18:19:12 SUCCESS    #1: NVIDIA GeForce RTX 3080 Ti [86]
# 18:19:12 INFO     Loading network snapshot from: models/ngp/Case_I/base.msgpack
# 18:19:14 DEBUG    GPUMemory: allocating 1.52 KB.
# 18:19:14 DEBUG    GPUMemory: allocating 156 B.
# 18:19:14 DEBUG    GPUMemory: allocating 156 B.
# 18:19:14 DEBUG    GPUMemory: allocating 156 B.
# 18:19:14 DEBUG    GPUMemory: allocating 156 B.
# 18:19:14 DEBUG    GPUMemory: allocating 8 B.
# 18:19:14 DEBUG    GPUMemory: allocating 1.22 KB.
# 18:19:14 DEBUG    GPUMemory: allocating 20 MB.
# 18:19:14 DEBUG    GPUMemory: allocating 40 MB.
# 18:19:14 DEBUG    GPUMemory: allocating 2 MB.
# 18:19:14 DEBUG    GPUMemory: allocating 64 KB.
# 18:19:14 INFO     GridEncoding:  Nmin=16 b=2.97199 F=4 T=2^19 L=8
# 18:19:14 DEBUG    GridEncoding at level 0: resolution=16 params_in_level=4096
# ...
