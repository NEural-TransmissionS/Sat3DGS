# %% [markdown]
# # Train

# %%
# screen -dmS 4dgs_Case_I -L -Logfile 4dgs_Case_I.log sh -c 'CUDA_VISIBLE_DEVICES=0 python 4DGaussians/train.py -s data_ns/Case_I --port 6014 --expname "4dgs/Case_I" --configs 4DGaussians/arguments/hypernerf/default.py'
# nvidia-smi dmon -s umc -i 0 -d 1 -f 4dgs_Case_I_gpu_util.log &
# 273 4163
# screen -dmS 4dgs_Case_II -L -Logfile 4dgs_Case_II.log sh -c 'CUDA_VISIBLE_DEVICES=1 python 4DGaussians/train.py -s data_ns/Case_II --port 6015 --expname "4dgs/Case_II" --configs 4DGaussians/arguments/hypernerf/default.py'
# nvidia-smi dmon -s umc -i 1 -d 1 -f 4dgs_Case_II_gpu_util.log &
# 12 4242
# screen -dmS 4dgs_Case_III -L -Logfile 4dgs_Case_III.log sh -c 'CUDA_VISIBLE_DEVICES=0 python 4DGaussians/train.py -s data_ns/Case_III --port 6016 --expname "4dgs/Case_III" --configs 4DGaussians/arguments/hypernerf/default.py'
# nvidia-smi dmon -s umc -i 0 -d 1 -f 4dgs_Case_III_gpu_util.log &

# screen -dmS 4dgs_Case_IV -L -Logfile 4dgs_Case_IV.log sh -c 'CUDA_VISIBLE_DEVICES=1 python 4DGaussians/train.py -s data_ns/Case_IV --port 6017 --expname "4dgs/Case_IV" --configs 4DGaussians/arguments/hypernerf/default.py'
# nvidia-smi dmon -s umc -i 1 -d 1 -f 4dgs_Case_IV_gpu_util.log &

# %% [markdown]
# # Render

# %%
# !python 4DGaussians/render.py --model_path "models/4dgs/Case_I"  --skip_train --configs 4DGaussians/arguments/hypernerf/default.py --skip_video
# !python 4DGaussians/render.py --model_path "models/4dgs/Case_II"  --skip_train --configs 4DGaussians/arguments/hypernerf/default.py --skip_video
# !python 4DGaussians/render.py --model_path "models/4dgs/Case_III"  --skip_train --configs 4DGaussians/arguments/hypernerf/default.py --skip_video
# !python 4DGaussians/render.py --model_path "models/4dgs/Case_IV"  --skip_train --configs 4DGaussians/arguments/hypernerf/default.py --skip_video
# Out:
# Looking for config file in models/4dgs/Case_I/cfg_args
# Config file found: models/4dgs/Case_I/cfg_args
# Rendering  models/4dgs/Case_I
# feature_dim: 48 [25/02 20:48:22]
# Loading trained model at iteration 14000 [25/02 20:48:22]
# Found transforms_train.json file, assuming Blender data set! [25/02 20:48:22]
# Reading Training Transforms [25/02 20:48:22]
# Reading Test Transforms [25/02 20:48:22]
# Generating Video Transforms [25/02 20:48:22]
# hello!!!! [25/02 20:48:22]
# Generating random point cloud (2000)... [25/02 20:48:22]
# Loading Training Cameras [25/02 20:48:22]
# Loading Test Cameras [25/02 20:48:22]
# Loading Video Cameras [25/02 20:48:22]
# Deformation Net Set aabb [1.29982098 1.29990645 1.29988719] [-1.29980838 -1.29981163 -1.29872349] [25/02 20:48:22]
# Voxel Plane: set aabb= Parameter containing:
# tensor([[ 1.2998,  1.2999,  1.2999],
#         [-1.2998, -1.2998, -1.2987]]) [25/02 20:48:22]
# ...
